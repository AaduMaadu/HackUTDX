# %%
import pandas as pd
sensor_data = pd.read_csv('sensor_readings.csv')
sensor_data.describe()
sensor_data
# Out:
#        Unnamed: 0        time  111111_ 40.595561_-105.14055_3  \
# 0               1  1681776002                          1030.0
# 1               2  1681776003                          1033.0
# 2               3  1681776004                          1022.0
# 3               4  1681776005                          1034.0
# 4               5  1681776006                          1037.5
# ...           ...         ...                             ...
# 83408       83409  1681862395                           853.0
# 83409       83410  1681862396                           852.5
# 83410       83411  1681862397                           852.0
# 83411       83412  1681862398                           859.0
# 83412       83413  1681862399                           855.0
#
#        111111_ 40.596108_-105.140583_4  111111_40.595556_-105.140069_2  \
# 0                               1049.0                          1166.0
# 1                               1051.0                          1163.0
# ...
